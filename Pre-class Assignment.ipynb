# %% [markdown]
# # 2019 Summer Camp Pre-Class Assignment
# *Cynthia Wang*
#
# ## 1 Getting Started
# ### Question 1.1 Python Convolution
# Python code written in HomeWorkCode.py
#
# ### Question 1.2 Filtering
# ```
# I⊙f = [0.5+0.5+1        2+0.75+0.25        1.5+0.5   ]
#        [0.5+0.5+0.5+0.25 0.25+2+0.5+1+1     1.5+1+0.25]
#        [2+0.5+0.25       0.5+1+0.5+0.25     0.5+1     ]
#      = [2     3     2   ]
#        [1.75  4.75  2.75]
#        [2.75  2.25  1.5 ]
#
# f⊙I = [0.5+1       1+0.5+0.5+0.25  0.25+2+0.5      ]
#        [1+1.5+0.25  0.25+2+0.5+1+1  0.5+0.5+0.5+0.25]
#        [0.5+1.5     2+0.75+0.25     0.5+0.5+1       ]
#      = [1.5   2.25  2.75]
#        [2.75  4.75  1.75]
#        [2     3     2   ]
# ```
# **Answer:** Commutative property doesn't hold for the filtering function.
#
# ## 2 Convolution
# ### Question 2.1
#
# ```
# g1 = [-1  1  1]       [1]
#      [-1  2  1]   ⊙  [1]
#      [-3  1  3]       [1]
#
#    = [-2  3  2]
#      [-5  4  5]
#      [-4  3  4]
# ```
# -----
# ```
# fxy = [-1  0  1]
#       [-1  0  1]
#       [-1  0  1]
#
# g2 = [-2  3  2]
#      [-5  4  5]
#      [-4  3  4]
# ```
#
# g1 = g2
#
# **Answer:** Associative property of convolution is verified.
#
# ### Question 2.2
# multiplication times of g1 = `2(9 * 3)` = 54
#
# addition times of g1 = `9 * 2` = 18
#
# multiplication times of g2 = `3 * 3 + 9 * 9` = 90
#
# addition times of g2 = `3 * 3 + 9` = 18
#
# ### Question 2.3
# Convolution made this image's left hand side darker and right hand side lighter.
#
# ## 3 Kernel Estimation and 4 Edge Moving
# *I did my best attempt at solving these questions, but I'm afraid that my understanding and math knowledge couldn't support me to give an explicit answer. I'm so sorry about this. I'll do my best to catch this up in the camp.*
